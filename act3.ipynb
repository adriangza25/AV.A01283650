# %% [markdown]
# # Actividad 3: Pivot Tables

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import seaborn as sns

# %%
df = pd.read_csv('datasets/antropometria-dataset.csv')
df.head(2)
# Out:
#     folio  intp  entidad desc_ent  sexo  edad  meses   peso  ropa  talla  ...  \
# 0  210295     2       21   PUEBLA     2    38      8  73.70     2  146.4  ...
# 1  101655     3       10  DURANGO     2    11     11  35.65     2  145.1  ...
#
#   hpresion tbrazo  htension  PrimaryLast  code_upm  est_dis est_urb est_marg  \
# 0    16:30      2     16:35            1     R2101        5       3        1
# 1    15:25      3     15:25            1     M1041        1       1        1
#
#         pondef  est_var
# 0  3470.002176      215
# 1   417.946672      101
#
# [2 rows x 26 columns]

# %%
pivot = pd.pivot_table(df, values = ['peso'], index = ['desc_ent'], aggfunc ={'peso':np.mean})
pivot
# Out:
#                                       peso
# desc_ent
# AGUASCALIENTES                   66.357786
# BAJA CALIFORNIA                  68.467270
# BAJA CALIFORNIA SUR              71.809198
# CAMPECHE                         65.418475
# CHIAPAS                          57.613775
# CHIHUAHUA                        66.656005
# COAHUILA DE ZARAGOZA             68.154142
# COLIMA                           68.743648
# DISTRITO FEDERAL                 65.119273
# DURANGO                          66.354922
# GUANAJUATO                       63.936390
# GUERRERO                         60.466315
# HIDALGO                          59.995917
# JALISCO                          66.697270
# MEXICO                           60.680850
# MICHOACAN DE OCAMPO              64.900000
# MORELOS                          63.541295
# NAYARIT                          66.541827
# NUEVO LEON                       67.239853
# OAXACA                           58.800067
# ...

# %%
pivot2 = pd.pivot_table(df, values = ['peso'], index = ['desc_ent'], columns = 'sexo', aggfunc ={'peso':np.mean})
pivot2
# Out:
#                                       peso
# sexo                                     1          2
# desc_ent
# AGUASCALIENTES                   69.985381  63.254292
# BAJA CALIFORNIA                  71.391818  65.893667
# BAJA CALIFORNIA SUR              75.561015  68.168959
# CAMPECHE                         68.622637  62.920493
# CHIAPAS                          58.365222  57.096111
# CHIHUAHUA                        68.892642  64.815295
# COAHUILA DE ZARAGOZA             68.873094  67.467348
# COLIMA                           70.998878  66.978393
# DISTRITO FEDERAL                 69.460661  61.654128
# DURANGO                          68.846451  64.400031
# GUANAJUATO                       65.008000  63.100995
# GUERRERO                         62.611437  58.899850
# HIDALGO                          61.747958  58.972554
# JALISCO                          67.076482  66.418111
# MEXICO                           63.140314  58.887882
# ...

# %%
df2 = pd.read_csv('datasets/adult.csv')
df2.head(2)
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
#
#         marital-status        occupation    relationship    race    sex  \
# 0        Never-married      Adm-clerical   Not-in-family   White   Male
# 1   Married-civ-spouse   Exec-managerial         Husband   White   Male
#
#    capital-gain  capital-loss  hours-per-week  native-country the label
# 0          2174             0              40   United-States     <=50K
# 1             0             0              13   United-States     <=50K

# %%
pivot3 = pd.pivot_table(df2, index = ['education', 'marital-status'], columns = ['sex'], values = ['age', 'hours-per-week'])
pivot3.head(60)
# Out:
#                                           age            hours-per-week  \
# sex                                    Female       Male         Female
# education   marital-status
#  10th        Divorced               45.343284  42.603774      37.059701
#              Married-civ-spouse     38.363636  46.936709      36.393939
#              Married-spouse-absent  36.714286  46.625000      34.571429
#              Never-married          22.742188  24.630901      26.968750
#              Separated              39.838710  39.000000      38.032258
#              Widowed                60.344828  56.100000      31.586207
#  11th        Divorced               41.531646  40.764706      37.481013
#              Married-civ-spouse     38.657143  42.987461      34.114286
#              Married-spouse-absent  34.142857  34.000000      36.428571
#              Never-married          21.423387  22.875740      25.334677
#              Separated              37.857143  35.650000      36.535714
# ...
